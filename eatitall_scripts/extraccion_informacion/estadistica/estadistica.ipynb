# %% [markdown]
# ## Correlaciones

# %%
import sys
sys.path.insert(1, '/home/eatitall_scripts')
sys.path.insert(1, '/home/root/pctobs/lib/python3.8/site-packages')
import pandas as pd
from extraccion_informacion.estadistica import estadistica

# %%
csv_path='./../../archivos/datos_con_10_ejemplos_reglas_y_extraccion_entidades.csv'

# %%
# Cargamos el archivo CSV
df = pd.read_csv(csv_path)

# %%
# columnas_seleccionadas = ['sexo', 'edad', 'acv', 'hba1c', 'fg', 'tg','talla','peso','tas','tad','estatina']

# df_subconjunto = df[columnas_seleccionadas]

# %%
# Llama a la función con tu dataset
matriz_correlacion = estadistica.buscar_correlaciones(df)

# Encontrar las 5 variables más relacionadas, por ejemplo
variables_mas_relacionadas = estadistica.encontrar_variables_mas_relacionadas(matriz_correlacion, 10, 0.99)

# Mostrar los resultados
print(variables_mas_relacionadas.to_string(index=False))
# Out:
#          Variable1          Variable2  Correlacion
# supera_fg_3_6meses                imc     0.989660
#               imci supera_fg_3_6meses     0.989651
#          plaquetas         s_insulina     0.989336
#                tas    fib4_3_6mesesF2     0.987829
#                cac                got     0.986507
#                 fg        fg_3_6meses     0.984954
#                tas  ERCcalculadabasal     0.981981
#                tas      CACmas30basal     0.981981
#    peso_s_3_6meses       imc_3_6meses     0.978828
#       ins_cardiaca                tad     0.977356
# /home/eatitall_scripts/extraccion_informacion/estadistica/estadistica.py:14: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones = df.corr(method='pearson')

# %%
# import seaborn as sns

estadistica.visualizar_correlaciones(df)
# Out:
# /home/eatitall_scripts/extraccion_informacion/estadistica/estadistica.py:45: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones = dataset.corr()
